# %%
import pandas as pd
import numpy as np
import optuna
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### 1. Load the preprocessed datasets

# %%
train = pd.read_csv(r"C:\Users\YILMAZ\Desktop\train_fe_scaled.csv")
test = pd.read_csv(r"C:\Users\YILMAZ\Desktop\train_fe_scaled.csv")
# scaled data sets were used

# %% [markdown]
# ### 2. Define features and target variable

# %%
target = "price_z"
X_train = train.drop(columns=[target])
y_train = train[target]

# %% [markdown]
# ### 3. Define the objective function for Optuna

# %%
def objective(trial):
    alpha = trial.suggest_float('alpha', 1.0, 1000.0, log=True)
    model = Ridge(alpha=alpha, random_state=42)

    cv = KFold(n_splits=5, shuffle=True, random_state=42)
    rmse = -cross_val_score(model, X_train, y_train,
                            cv=cv,
                            scoring='neg_root_mean_squared_error').mean()
    return rmse

# %% [markdown]
# ### 4. Run Optuna study to find the best alpha (regularization strength)

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50, timeout=900)

print("\n Best hyperparameter found by Optuna:")
print(study.best_params)
# Out:
# [I 2025-05-23 06:43:41,856] A new study created in memory with name: no-name-b57c8e3e-00ac-4192-8c42-1b9e8dc9550f
# [I 2025-05-23 06:43:42,308] Trial 0 finished with value: 170105.78785147294 and parameters: {'alpha': 1.363743688614485}. Best is trial 0 with value: 170105.78785147294.
# [I 2025-05-23 06:43:42,671] Trial 1 finished with value: 170114.88691847533 and parameters: {'alpha': 228.23963381335375}. Best is trial 0 with value: 170105.78785147294.
# [I 2025-05-23 06:43:43,055] Trial 2 finished with value: 170105.95310118358 and parameters: {'alpha': 32.08857629024616}. Best is trial 0 with value: 170105.78785147294.
# [I 2025-05-23 06:43:43,433] Trial 3 finished with value: 170105.78722004552 and parameters: {'alpha': 2.64461710601004}. Best is trial 3 with value: 170105.78722004552.
# [I 2025-05-23 06:43:43,787] Trial 4 finished with value: 170105.9249339821 and parameters: {'alpha': 29.506185831777383}. Best is trial 3 with value: 170105.78722004552.
# [I 2025-05-23 06:43:44,141] Trial 5 finished with value: 170105.78729752518 and parameters: {'alpha': 4.066930468023004}. Best is trial 3 with value: 170105.78722004552.
# [I 2025-05-23 06:43:44,474] Trial 6 finished with value: 170105.83947089655 and parameters: {'alpha': 19.37316952926288}. Best is trial 3 with value: 170105.78722004552.
# [I 2025-05-23 06:43:44,818] Trial 7 finished with value: 170105.78755077053 and parameters: {'alpha': 1.8191085675542789}. Best is trial 3 with value: 170105.78722004552.
# [I 2025-05-23 06:43:45,183] Trial 8 finished with value: 170123.34071726585 and parameters: {'alpha': 323.06205981061305}. Best is trial 3 with value: 170105.78722004552.
# [I 2025-05-23 06:43:45,516] Trial 9 finished with value: 170105.7997304842 and parameters: {'alpha': 11.122592507359148}. Best is trial 3 with value: 170105.78722004552.
# [I 2025-05-23 06:43:45,861] Trial 10 finished with value: 170109.12909262246 and parameters: {'alpha': 136.43092984180004}. Best is trial 3 with value: 170105.78722004552.
# [I 2025-05-23 06:43:46,215] Trial 11 finished with value: 170105.78738724574 and parameters: {'alpha': 4.297744150568624}. Best is trial 3 with value: 170105.78722004552.
# [I 2025-05-23 06:43:46,569] Trial 12 finished with value: 170105.78769965464 and parameters: {'alpha': 4.865736742130032}. Best is trial 3 with value: 170105.78722004552.
# [I 2025-05-23 06:43:46,932] Trial 13 finished with value: 170105.7876178213 and parameters: {'alpha': 4.737635946246921}. Best is trial 3 with value: 170105.78722004552.
# [I 2025-05-23 06:43:47,309] Trial 14 finished with value: 170106.92817283515 and parameters: {'alpha': 79.90381001448303}. Best is trial 3 with value: 170105.78722004552.
# [I 2025-05-23 06:43:47,676] Trial 15 finished with value: 170187.97382793698 and parameters: {'alpha': 764.7767938724068}. Best is trial 3 with value: 170105.78722004552.
# [I 2025-05-23 06:43:48,038] Trial 16 finished with value: 170105.787262042 and parameters: {'alpha': 2.4863860600849566}. Best is trial 3 with value: 170105.78722004552.
# [I 2025-05-23 06:43
# [I 2025-05-23 06:43:57,521] Trial 39 finished with value: 170105.78716781148 and parameters: {'alpha': 3.4933818653181237}. Best is trial 35 with value: 170105.78716163733.
# [I 2025-05-23 06:43:57,874] Trial 40 finished with value: 170105.94700007697 and parameters: {'alpha': 31.548753765908618}. Best is trial 35 with value: 170105.78716163733.
# [I 2025-05-23 06:43:58,754] Trial 41 finished with value: 170105.78719430565 and parameters: {'alpha': 3.6739621949497727}. Best is trial 35 with value: 170105.78716163733.
# [I 2025-05-23 06:43:59,862] Trial 42 finished with value: 170105.78719323044 and parameters: {'alpha': 3.6680554555160176}. Best is trial 35 with value: 170105.78716163733.
# [I 2025-05-23 06:44:00,236] Trial 43 finished with value: 170105.7894835556 and parameters: {'alpha': 6.618193300907448}. Best is trial 35 with value: 170105.78716163733.
# [I 2025-05-23 06:44:00,601] Trial 44 finished with value: 170105.78715676902 and parameters: {'alpha': 3.3610231165426154}. Best is trial 44 with value: 170105.78715676902.
# [I 2025-05-23 06:44:00,942] Trial 45 finished with value: 170105.78790748242 and parameters: {'alpha': 1.2907735137283527}. Best is trial 44 with value: 170105.78715676902.
# [I 2025-05-23 06:44:01,298] Trial 46 finished with value: 170105.78826467288 and parameters: {'alpha': 5.56670110782652}. Best is trial 44 with value: 170105.78715676902.
# [I 2025-05-23 06:44:01,672] Trial 47 finished with value: 170105.78754526103 and parameters: {'alpha': 1.8288426469988066}. Best is trial 44 with value: 170105.78715676902.
# [I 2025-05-23 06:44:02,016] Trial 48 finished with value: 170106.31832726463 and parameters: {'alpha': 55.19405722494512}. Best is trial 44 with value: 170105.78715676902.
# [I 2025-05-23 06:44:02,369] Trial 49 finished with value: 170105.78715352807 and parameters: {'alpha': 3.161125012584329}. Best is trial 49 with value: 170105.78715352807.
#  Best hyperparameter found by Optuna:
# {'alpha': 3.161125012584329}

# %% [markdown]
# ### 6. Train the Ridge model using the best alpha

# %%
best_model = Ridge(alpha=study.best_params['alpha'], random_state=42)
best_model.fit(X_train, y_train)
# Out:
# Ridge(alpha=3.161125012584329, random_state=42)

# %% [markdown]
# ### 7. Evaluate model performance using 5-fold cross-validation

# %%
cv = KFold(n_splits=5, shuffle=True, random_state=42)

cv_rmse = -cross_val_score(best_model, X_train, y_train, scoring='neg_root_mean_squared_error', cv=cv)
cv_mae = -cross_val_score(best_model, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv)
cv_r2 = cross_val_score(best_model, X_train, y_train, scoring='r2', cv=cv)

print("\n Tuned Ridge Regression 5-Fold Cross-Validation Results:")
print(f"🔹 RMSE: {cv_rmse.mean():,.2f} ± {cv_rmse.std():,.2f}")
print(f"🔹 MAE: {cv_mae.mean():,.2f} ± {cv_mae.std():,.2f}")
print(f"🔹 R²: {cv_r2.mean():.4f} ± {cv_r2.std():.4f}")
# Out:
#  Tuned Ridge Regression 5-Fold Cross-Validation Results:
# 🔹 RMSE: 170,105.79 ± 2,707.44
# 🔹 MAE: 118,579.12 ± 626.37
# 🔹 R²: 0.8436 ± 0.0018
